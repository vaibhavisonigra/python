# %%
print("welcome to the personal data colletor")
name = str(input("enter your name:"))
age = int(input("enter your age:"))
height = float(input("enter your height:"))
fav_num = int(input("enter your favourite number:"))
print("name:", name, type(name), "Memory address:", id(name))
print("age:", age, type(age), "Memory address:" , id(age))
print("height", height, type(height), "Memory address:" , id(height))
print("favourite", fav_num, type(fav_num), "Memory address:", id(fav_num))
print("Thank you for ues my project.")
# Out:
# welcome to the personal data colletor
# name: vaibhavi <class 'str'> Memory address: 2386937641776
# age: 18 <class 'int'> Memory address: 140733891069592
# height 1.69 <class 'float'> Memory address: 2386926885936
# favourite 3 <class 'int'> Memory address: 140733891069112
# Thank you for ues my project.
